# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
letters_series = pd.Series([1, 3, 4, 5, 6, 7])
letters_series
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# dtype: int64

# %%
a = np.arange(0, 5)
a
# Out:
# array([0, 1, 2, 3, 4])

# %%
b = np.arange(5, 10)
b
# Out:
# array([5, 6, 7, 8, 9])

# %%
res = []
for i in range(len(a)):
    res.append(a[i] + b[i])
np.array(res)
# Out:
# array([ 5,  7,  9, 11, 13])

# %%
# initialize the Python lists  
lt1 = [5, 10, 15, 20, 25, 30]  
lt2 = [2, 4, 6, 8, 10, 12]  
  
# print the original list element  
print ( " Python Original list 1: " + str (lt1))  
print ( "Python Original list 2: " + str (lt2))  
  
# use naive method to add two list.  
res_lt = [] # declaration of the list  
for x in range (0, len (lt1)):  
    res_lt.append( lt1[x] + lt2[x])  
  
# Display the sum of two list in Python  
print ( " Addition of the list lt1 and lt2 is: " + str (res_lt))
# Out:
#  Python Original list 1: [5, 10, 15, 20, 25, 30]
# Python Original list 2: [2, 4, 6, 8, 10, 12]
#  Addition of the list lt1 and lt2 is: [7, 14, 21, 28, 35, 42]

# %%
a = np.arange(0, 6)
a
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
a + 10
# Out:
# array([10, 11, 12, 13, 14, 15])

# %%
(users.merge(roles, 
            left_on='role_id', 
            right_on='id', 
            how='outer')
    .drop(columns='role_id')
    .rename(columns={'id_x': 'id', 
                     'name_x': 'employee',
                     'id_y': 'role_id',
                     'name_y': 'role'}
            )
)

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
0.3 - 0.2
# Out:
# 0.09999999999999998

# %%
0.3 - 0.2 == 0.09999999999999998
# Out:
# True

# %%
0.1 + 0.2 == 0.30000000000000004
# Out:
# True

# %%
0.1 + 0.2 = 0.30000000000000004
# Out:
#   File "/var/folders/5k/zptdym41293159jft7y2b6cm0000gp/T/ipykernel_87510/1377189166.py", line 1
#     0.1 + 0.2 = 0.30000000000000004
#     ^
# SyntaxError: cannot assign to operator

# %%
'HELLO' == 'hello'.upper()
# Out:
# True

# %%
'hello'.capitalize()
# Out:
# 'Hello'

# %%
import math

# %%
fig = plt.figure()

x = np.arange(0, math.pi*2, 0.025)
y1 = np.sin(x)
y2 = np.cos(x)

axes = fig.add_axes([0, 0, 1, 1])
axes1 = fig.add_axes([0, 1, 1, 1])
axes.plot(x, y1)
axes1.plot(x, y2)

# %%
import seaborn as sns

df = sns.load_dataset('tips')
df.to_clipboard()

# %%
np.random.choice
# Out:
# <function RandomState.choice>

# %%
die_distribution = stats.randint(1, 7)
die_distribution

# %%
die_distribution.rvs(10)
# Out:
# array([3, 2, 2, 3, 4, 5, 4, 1, 4, 2])

# %%
die_distribution. cdf(5)
# Out:
# 0.8333333333333334

# %%
die_distribution.ppf(0.7)
# Out:
# 5.0

# %%
np.random.normal(100, 1.5)
# Out:
# 100.34894005306812

# %%
np.random.choice(7, 3)
# Out:
# array([5, 1, 1])

# %%
rolls = np.random.choice([1, 2, 3, 4, 5, 6], n_trials * n_dice).reshape(nrows, ncols)
rolls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5k/zptdym41293159jft7y2b6cm0000gp/T/ipykernel_29981/3004614077.py in <module>
# ----> 1 rolls = np.random.choice([1, 2, 3, 4, 5, 6], n_trials * n_dice).reshape(nrows, ncols)
#       2 rolls
#
# NameError: name 'n_trials' is not defined

# %%
rolls = np.random.choice([1, 2, 3, 4, 5, 6])
rolls
# Out:
# 1

# %%
n_trials = nrows = 1
n_dice = ncols = 3

rolls = np.random.choice([1, 2, 3, 4, 5, 6], n_trials * n_dice)
rolls
# Out:
# array([6, 1, 6])

# %%
n_trials = nrows = 10**5
n_dice = ncols = 3

rolls = np.random.choice([1, 2, 3, 4, 5, 6], n_trials * n_dice).reshape(n_trials, n_dice)
rolls
# Out:
# array([[3, 2, 4],
#        [2, 5, 2],
#        [5, 4, 1],
#        ...,
#        [6, 5, 2],
#        [3, 4, 5],
#        [2, 2, 6]])

# %%
sums_by_trial = rolls.sum(axis=1)
sums_by_trial
# Out:
# array([ 9,  9, 10, ..., 13, 12, 10])

# %%
wins = sums_by_trial > 12
wins
# Out:
# array([False, False, False, ...,  True, False, False])

# %%
win_rate = wins.astype(int).mean()
win_rate
# Out:
# 0.26206

# %%
expected_winnings = win_rate * 15
expected_winnings
# Out:
# 3.9309000000000003

# %%
cost = 5
expected_profit = expected_winnings - cost
expected_profit
# Out:
# -1.0690999999999997

# %%
np.random.randn(10, 10)
# Out:
# array([[ 1.33283746, -0.16582612,  0.82275853,  0.03870217, -0.88123149,
#         -0.62647128, -0.66452267, -0.79048059,  2.39693373, -0.10805705],
#        [-0.54739743, -0.21960555,  1.06642127,  0.09957745, -0.64334434,
#          0.06840765,  0.55964828,  1.0374522 ,  0.78056947, -1.34508326],
#        [-0.72858395,  0.28093474, -0.01881399, -1.16178474,  1.46198148,
#          0.67274686, -0.46435514,  1.54910473, -0.80309097, -0.58655007],
#        [ 1.13603348, -0.2376533 ,  2.42368674, -0.38678121, -0.33277857,
#          0.30730099,  0.58831793,  0.57021566,  1.2367596 , -0.4325256 ],
#        [-0.29403484,  0.33948411, -1.15429789, -1.3105166 , -0.97325582,
#         -1.79333669, -2.01863427, -1.14188321,  0.17223129, -1.37365903],
#        [-0.31463722, -0.18193354,  0.3305618 , -0.51067831,  0.85820096,
#          0.34073666,  0.74535258,  0.43191028,  1.05843968,  0.53888456],
#        [-0.07019076, -1.6371655 , -0.52936424, -0.56200658,  0.59120663,
#         -0.61310859, -0.28724401,  0.35244586,  0.09906469, -0.61331523],
#        [ 0.81908236, -1.53123037, -0.74144474, -0.58245649,  0.41876288,
#         -1.76801383, -1.41624794,  0.01714086, -0.98949733, -0.79761087],
#        [-0.865132  ,  0.26900588, -0.05643892, -0.0500202 , -1.13714221,
#         -0.14273736,  1.01659057, -0.61955836,  0.79612756,  1.16914898],
#        [ 0.15565232,  1.42165064,  0.28650427, -0.63978485, -2.35483379,
#         -0.7466848 , -2.15426105, -0.06459913,  0.26437412, -1.33790007]])

# %%
# p_nap = .3
# ndays = ncols = 2
# n_simulated_weekends = nrows = 10**5

# %%
data = np.random.random((nrows, ncols))
data
# Out:
# array([[0.15393909, 0.51973237],
#        [0.72435876, 0.19387706],
#        [0.00588585, 0.39810504],
#        ...,
#        [0.41673228, 0.89689401],
#        [0.19731914, 0.55577581],
#        [0.02485741, 0.23107255]])

# %%
(pd.DataFrame(rolls).apply(lambda row: 3 in row.values, axis=1).mean())
# Out:
# 0.42224

# %%
sales = { 'apple': 2, 'orange': 3, 'grapes': 4 }

sales.values()
# Out:
# dict_values([2, 3, 4])

# %%
from scipy.stats import beta
beta.rvs(98,1000000)
# Out:
# 9.178288546912215e-05

# %%
die_distribution = stats.randint(1, 7)


n = 10**7

x = die_distribution.rvs(n)

plt.hist(x, bins=range(0, 9), align='left', width=1, edgecolor='black')
plt.title(f'Outcome of {n:,} Dice Rolls')
# Out:
# Text(0.5, 1.0, 'Outcome of 10,000,000 Dice Rolls')
